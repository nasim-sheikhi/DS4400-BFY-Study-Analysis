# %%
import pandas as pd

# %%
filepath = 'ICPSR_37871/DS0002/37871-0002-Data.tsv'

df_bfy = pd.read_csv(filepath, delimiter='\t')
print(df_bfy.shape)
df_bfy.head()
# Out:
# (1000, 2010)
#   MSMSPROJECTIDA1 VERIFYR_S_1A1 VERIFYR_S_2A1 VERIFYR_S_3A1 VERIFYR_S_4A1  \
# 0               1             1
# 1               1             1
# 2               1             1
# 3               1             1
# 4               1             1
#
#   VERIFYR_S_5A1 CORRGENDERCHILDA1 BABYGENDERA1 CHILDWELLA1 CHILDWELL1A1  ...  \
# 0                                            1           1               ...
# 1                                            5           1               ...
# 2                                            5           1               ...
# 3                                            5           1               ...
# 4                                            1           1               ...
#
#   HHAGE1CONTRGRANDPAA1 HHAGE1CONTROTHERADULTA1 HHAGE1CONTRCHILDA1 CORTISOLA1  \
# 0                    1                       0                  0     2673.9
# 1                    0                       0                  0       15.8
# ...

# %% [markdown]
# Dataset includes several checkpoints throughout interview and features with no data. Filter data to include only survey responses for family life, maternal health, and child health:

# %%
# Keep rows that 'CHILDWELL1A1' == 1
# Keep rows that 'CHILDATHOMEA1' == 1
# Keep rows that 'ELIGIBILITYA1' == '.'
# Collapse cols of number of adults/children in family, number of adults/children who contribute to income?
# Remove columns with no data (household members 12-25, some ethnicity Qs, other household info,
                                # household child info, child language)
# Collapse RWORKMONTHS cols into months that RESP worked since child was born (NEED CHILD AGE IN MO) (1-21)
# Collapse RWORKFTMONTHS cols into months that RSEP worked full-time since child was born (1-21)
# Collapse MATERNITYMONTHS cols into months that RESP received paid maternity leave since child was born (1-21)
# Collapse MATERNITYSAMEJOBMONTHS cols into months that RESP took unpaid maternity leave since child was born (1-21)
# Collapse MOMNOTWBABYMONTHS cols into months that RESP lived apart from baby (1-21)
# Collapse BENEFITSMAIN cols into benefits that RESP receives at main job
# Collapse ISSUES cols into issues that interfere with RESP's ability to work (childcare-other)
# Collapse SERVICESSUPPORT cols into services that each family receives (1-12)
# Collapse HAPPLIANCES cols into home appliances that each family has (1-5)
# Collapse HCOMPUTER cols into computers that each family has (1-3)

cols_to_remove = ['MSMSPROJECTIDA1', 'VERIFYR_S_1A1', 'VERIFYR_S_2A1', 'VERIFYR_S_3A1', 'VERIFYR_S_4A1',
                 'VERIFYR_S_5A1', 'CORRGENDERCHILDA1', 'WHERELIVEA1', 'TIMELIVEA1', 'WHENSTOPA1', 'WHERELIVEMOSTA1',
                 'LIVEEXPECTATIONA1', 'CHILDNOTHOMEA1', 'CHILDNOTHOME1A1', 'CHILDNOTHOME2A1',
                 'INSTRUMENTA1', 'INSTSELECTEDA1', 'VOL_STMTA1', 'RECORDEDIW_CONSENTA1', 'LANGCHKPTA1',
                 'SECA_DONEA1', 'MRANDOMA1', 'IWDONEA1', 'IWCOMPLETEA1', 'VERSIONDATEA1',
                 'CONTACTATTEMPTTIMEA1', 'CURRENTSECSA1', 'TOTALSECSA1', 'TOTALMINSA1', 'IWSTARTDATEA1',
                 'IWCURRDATEA1', 'TS_BEGINIWA1', 'TS_ENDIWA1', 'IWTOTALA1', 'RESPFNAMEA1', 'RESPLNAMEA1',
                 'CHILDFNAMEA1', 'CHILDMNAMEA1', 'CHILDLNAMEA1', 'HHMEMNAME_A_1A1', 'HHMEMREL_A_1A1',
                 'MONTH_A_1A1', 'YEAR_A_1A1', 'HHMEMCONTR_A_1A1', 'HHMEMNAME_A_2A1', 'HHMEMGENDER_A_2A1',
                 'HHMEMREL_A_2A1', 'MONTH_A_2A1', 'YEAR_A_2A1', 'HHMEMCONTR_A_2A1', 'HHMEMNAME_A_3A1',
                 'HHMEMGENDER_A_3A1', 'HHMEMREL_A_3A1', 'MONTH_A_3A1', 'YEAR_A_3A1', 'HHMEMCONTR_A_3A1',
                 'HHMEMNAME_A_4A1', 'HHMEMGENDER_A_4A1', 'HHMEMREL_A_4A1', 'MONTH_A_4A1', 'YEAR_A_4A1',
                 'HHMEMCONTR_A_4A1', 'HHMEMNAME_A_5A1', 'HHMEMGENDER_A_5A1', 'HHMEMREL_A_5A1', 
                 'MONTH_A_5A1', 'YEAR_A_5A1', 'HHMEMCONTR_A_5A1', 'HHMEMNAME_A_6A1', 'HHMEMGENDER_A_6A1',
                 'HHMEMREL_A_6A1', 'MONTH_A_6A1', 'YEAR_A_6A1', 'HHMEMCONTR_A_6A1', 'HHMEMNAME_A_7A1',
                 'HHMEMGENDER_A_7A1', 'HHMEMREL_A_7A1', 'MONTH_A_7A1', 'YEAR_A_7A1', 'HHMEMCONTR_A_7A1',
                 'HHMEMNAME_A_8A1', 'HHMEMGENDER_A_8A1', 'HHMEMREL_A_8A1', 'MONTH_A_8A1', 'YEAR_A_8A1',
                 'HHMEMCONTR_A_8A1', 'HHMEMNAME_A_9A1', 'HHMEMGENDER_A_9A1', 'HHMEMREL_A_9A1',
                 'MONTH_A_9A1', 'YEAR_A_9A1', 'HHMEMCONTR_A_9A1', 'HHMEMNAME_A_10A1', 'HHMEMGENDER_A_10A1',
                 'HHMEMREL_A_10A1', 'MONTH_A_10A1', 'YEAR_A_10A1', 'HHMEMCONTR_A_10A1', 'HHMEMNAME_A_11A1',
                 'HHMEMGENDER_A_11A1', 'HHMEMREL_A_11A1', 'MONTH_A_11A1', 'YEAR_A_11A1', 'HHMEMCONTR_A_11A1',
                 'STATE_DELETEA1', 'GIFTIDA1', 'CARDSETUPA1', 'HHMEMAGE_A_1A1', 'HHMEMAGE_A_2A1',
                 'HHMEMAGE_A_3A1', 'HHMEMAGE_A_4A1', 'HHMEMAGE_A_5A1', 'HHMEMAGE_A_6A1', 'HHMEMAGE_A_7A1',
                 'HHMEMAGE_A_8A1', 'HHMEMAGE_A_9A1', 'HHMEMAGE_A_10A1', 'HHMEMAGE_A_11A1', 'HHMEMAGE_A_12A1',
                 'HHMEMAGE_A_13A1', 'HHMEMAGE_A_14A1', 'HHMEMAGE_A_15A1', 'HHMEMAGE_A_16A1', 'HHMEMAGE_A_17A1',
                 'HHMEMAGE_A_18A1', 'HHMEMAGE_A_19A1', 'HHMEMAGE_A_20A1', 'HHMEMAGE_A_21A1', 'HHMEMAGE_A_22A1',
                 'HHMEMAGE_A_23A1', 'HHMEMAGE_A_24A1', 'HHMEMAGE_A_25A1', 'CORRCHILDNAMEFA1',
                 'CORRCHILDNAMELA1', 'CORRCHILDNAMELCONFIRMA1', 'CORRCHILDNAMEL2A1', 'NAMECOPYFLAGA1',
                 'DOBCOPYFLAGA1', 'NAMEFA1', 'NAMEMA1', 'NAMELA1', 'NAMEL2A1', 'DOD_MOA1', 'DOB_YR_B_1A1',
                 'MOMDEMINTROA1', 'MOMETHNIC_S_1A1', 'MOMETHNIC_S_2A1', 'MOMETHNIC_S_3A1',
                 'MOMETHNICOA1', 'MOMRACE_S_2A1', 'MOMRACE_S_3A1', 'MOMRACEOA1', 'ADULTHHROSTERINTROA1',
                 'ROSTERITERATIONCOUNT_B_1A1', 'OTHERADULTSINHHA1', 'HHMEMNAME_A_26A1',
                 'HHMEMLIVINGWITH_A_1A1', 'HHMEMREL_A_26A1', 'HHMEMSEX_A_1A1', 'HHMEMAGE_A_26A1',
                 'HHMEMDOB_A_1A1', 'DOB_MO_A_1A1', 'DOB_YR_A_1A1', 'HHMEMCONTR_A_26A1', 'HHOTHADULTS_A_1A1',
                 'HHMEMNAME_A_27A1', 'HHMEMLIVINGWITH_A_2A1', 'HHMEMREL_A_27A1', 'HHMEMSEX_A_2A1',
                 'HHMEMAGE_A_27A1', 'HHMEMDOB_A_2A1', 'DOB_MO_A_2A1', 'DOB_YR_A_2A1', 'HHMEMCONTR_A_27A1',
                 'HHOTHADULTS_A_2A1', 'HHMEMNAME_A_28A1', 'HHMEMLIVINGWITH_A_3A1', 'HHMEMREL_A_28A1',
                 'HHMEMSEX_A_3A1', 'HHMEMAGE_A_28A1', 'HHMEMDOB_A_3A1', 'DOB_MO_A_3A1', 'DOB_YR_A_3A1',
                 'HHMEMCONTR_A_28A1', 'HHOTHADULTS_A_3A1', 'HHMEMNAME_A_29A1', 'HHMEMLIVINGWITH_A_4A1',
                 'HHMEMREL_A_29A1', 'HHMEMSEX_A_4A1', 'HHMEMAGE_A_29A1', 'HHMEMDOB_A_4A1', 'DOB_MO_A_4A1',
                 'DOB_YR_A_4A1', 'HHMEMCONTR_A_29A1', 'HHOTHADULTS_A_4A1', 'HHMEMNAME_A_30A1',
                 'HHMEMLIVINGWITH_A_5A1', 'HHMEMREL_A_30A1', 'HHMEMSEX_A_5A1', 'HHMEMAGE_A_30A1',
                 'HHMEMDOB_A_5A1', 'DOB_MO_A_5A1', 'DOB_YR_A_5A1', 'HHMEMCONTR_A_30A1', 'HHOTHADULTS_A_5A1',
                 'HHMEMNAME_A_31A1', 'HHMEMLIVINGWITH_A_6A1', 'HHMEMREL_A_31A1', 'HHMEMSEX_A_6A1',
                 'HHMEMAGE_A_31A1', 'HHMEMDOB_A_6A1', 'DOB_MO_A_6A1', 'DOB_YR_A_6A1', 'HHMEMCONTR_A_31A1',
                 'HHOTHADULTS_A_6A1', 'HHMEMNAME_A_32A1', 'HHMEMREL_A_32A1', 'HHMEMSEX_A_7A1',
                 'HHMEMAGE_A_32A1', 'DOB_MO_A_7A1', 'DOB_YR_A_7A1', 'HHMEMCONTR_A_32A1', 'HHOTHADULTS_A_7A1',
                 'HHROSTCOPYFLAGA1', 'CHILDHHROSTERINTROA1', 'ROSTERITERATIONCOUNT_B_2A1',
                  'OTHERCHILDINHHA1', 'CHILDHHMEMNAME_A_1A1',
                 'CHILDHHMEMLIVINGWITH_A_1A1', 'CHILDHHMEMREL_A_1A1', 'CHILDHHMEMGENDER_A_1A1',
                 'CHILDHHMEMAGE_A_1A1', 'CHILDHHMEMDOB_A_1A1', 'DOB_MO_A_26A1', 'DOB_YR_A_26A1',
                 'HHCHILDJOB_A_1A1', 'HHCHILDCONTR_A_1A1', 'HHOTHCHILDREN_A_1A1', 'CHILDHHMEMNAME_A_2A1',
                 'CHILDHHMEMLIVINGWITH_A_2A1', 'CHILDHHMEMREL_A_2A1', 'CHILDHHMEMGENDER_A_2A1',
                 'CHILDHHMEMAGE_A_2A1', 'CHILDHHMEMDOB_A_2A1', 'DOB_MO_A_27A1', 'DOB_YR_A_27A1',
                 'HHCHILDJOB_A_2A1', 'HHCHILDCONTR_A_2A1', 'HHOTHCHILDREN_A_2A1', 'CHILDHHMEMNAME_A_3A1',
                 'CHILDHHMEMLIVINGWITH_A_3A1', 'CHILDHHMEMREL_A_3A1', 'CHILDHHMEMGENDER_A_3A1',
                 'CHILDHHMEMAGE_A_3A1', 'CHILDHHMEMDOB_A_3A1', 'DOB_MO_A_28A1', 'DOB_YR_A_28A1', 'HHCHILDJOB_A_3A1',
                 'HHCHILDCONTR_A_3A1', 'HHOTHCHILDREN_A_3A1', 'CHILDHHMEMNAME_A_4A1', 'CHILDHHMEMLIVINGWITH_A_4A1',
                 'CHILDHHMEMREL_A_4A1', 'CHILDHHMEMGENDER_A_4A1', 'CHILDHHMEMAGE_A_4A1', 'CHILDHHMEMDOB_A_4A1',
                 'DOB_YR_A_29A1', 'HHCHILDJOB_A_4A1', 'HHCHILDCONTR_A_4A1', 'HHOTHCHILDREN_A_4A1',
                 'CHILDHHMEMNAME_A_5A1', 'CHILDHHMEMLIVINGWITH_A_5A1', 'CHILDHHMEMREL_A_5A1', 'CHILDHHMEMGENDER_A_5A1',
                 'CHILDHHMEMAGE_A_5A1', 'CHILDHHMEMDOB_A_5A1', 'DOB_MO_A_30A1', 'DOB_YR_A_30A1',
                 'HHCHILDJOB_A_5A1', 'HHCHILDCONTR_A_5A1', 'HHOTHCHILDREN_A_5A1', 'CHILDHHMEMNAME_A_6A1',
                 'CHILDHHMEMLIVINGWITH_A_6A1', 'CHILDHHMEMREL_A_6A1', 'CHILDHHMEMGENDER_A_6A1',
                 'CHILDHHMEMAGE_A_6A1', 'CHILDHHMEMDOB_A_6A1', 'DOB_MO_A_31A1', 'DOB_YR_A_31A1',
                 'HHCHILDJOB_A_6A1', 'HHCHILDCONTR_A_6A1', 'HHOTHCHILDREN_A_6A1', 'CHILDHHMEMNAME_A_7A1',
                 'CHILDHHMEMLIVINGWITH_A_7A1', 'CHILDHHMEMREL_A_7A1', 'CHILDHHMEMGENDER_A_7A1',
                 'CHILDHHMEMAGE_A_7A1', 'CHILDHHMEMDOB_A_7A1', 'DOB_MO_A_32A1', 'DOB_YR_A_32A1',
                 'HHCHILDJOB_A_7A1', 'HHCHILDCONTR_A_7A1', 'HHOTHCHILDREN_A_7A1', 'CHILDHHMEMNAME_A_8A1',
                 'CHILDHHMEMLIVINGWITH_A_8A1', 'CHILDHHMEMREL_A_8A1', 'CHILDHHMEMGENDER_A_8A1',
                 'CHILDHHMEMAGE_A_8A1', 'CHILDHHMEMDOB_A_8A1', 'DOB_MO_A_33A1', 'DOB_YR_A_33A1',
                 'HHCHILDJOB_A_8A1', 'HHCHILDCONTR_A_8A1', 'HHOTHCHILDREN_A_8A1', 'CHILDHHMEMNAME_A_9A1',
                 'CHILDHHMEMLIVINGWITH_A_9A1', 'CHILDHHMEMREL_A_9A1', 'CHILDHHMEMGENDER_A_9A1',
                 'CHILDHHMEMAGE_A_9A1', 'CHILDHHMEMDOB_A_9A1', 'DOB_MO_A_34A1', 'DOB_YR_A_34A1',
                 'HHCHILDJOB_A_9A1', 'HHCHILDCONTR_A_9A1', 'HHOTHCHILDREN_A_9A1', 'CHILDHHMEMNAME_A_10A1',
                 'CHILDHHMEMLIVINGWITH_A_10A1', 'CHILDHHMEMREL_A_10A1', 'CHILDHHMEMGENDER_A_10A1',
                 'CHILDHHMEMAGE_A_10A1', 'CHILDHHMEMDOB_A_10A1', 'DOB_MO_A_35A1', 'DOB_YR_A_35A1',
                 'HHOTHCHILDREN_A_10A1', 'CHILDHHMEMNAME_A_11A1', 'CHILDHHMEMLIVINGWITH_A_11A1',
                 'CHILDHHMEMREL_A_11A1', 'CHILDHHMEMGENDER_A_11A1', 'CHILDHHMEMAGE_A_11A1',
                 'CHILDHHMEMDOB_A_11A1', 'DOB_MO_A_36A1', 'DOB_YR_A_36A1', 'HHOTHCHILDREN_A_11A1',
                 'CHILDROSTCOPYFLAGA1', 'SECC_DONEA1', 'SUBPARALLELS_DONEA1', 'PARALLEL_MENUA1',
                 'PARALLEL_EXITA1', 'INTRO_B_1A1', 'YIRINTROA1', 'BREASTFEEDMONTHS_S_1A1',
                 'BREASTFEEDMONTHS_S_2A1', 'BREASTFEEDMONTHS_S_3A1', 'BREASTFEEDMONTHS_S_4A1',
                 'BREASTFEEDMONTHS_S_5A1', 'BREASTFEEDMONTHS_S_6A1', 'BREASTFEEDMONTHS_S_7A1',
                 'BREASTFEEDMONTHS_S_8A1', 'BREASTFEEDMONTHS_S_9A1', 'BREASTFEEDMONTHS_S_10A1',
                 'BREASTFEEDMONTHS_S_11A1', 'BREASTFEEDMONTHS_S_12A1', 'BREASTFEEDMONTHS_S_13A1',
                 'BREASTFEEDMONTHS_S_14A1', 'BREASTFEEDMONTHS_S_15A1', 'BREASTFEEDMONTHS_S_16A1',
                 'BREASTFEEDMONTHS_S_17A1', 'BREASTFEEDMONTHS_S_18A1', 'BREASTFEEDMONTHS_S_19A1',
                 'BREASTFEEDMONTHS_S_20A1', 'BREASTFEEDMONTHS_S_21A1', 'NOCURRENTBREASTFEED_S_1A1',
                 'NOCURRENTBREASTFEED_S_2A1', 'NOCURRENTBREASTFEED_S_3A1', 'NOCURRENTBREASTFEED_S_4A1',
                 'NOCURRENTBREASTFEED_S_5A1', 'NOCURRENTBREASTFEED_S_6A1', 'NOCURRENTBREASTFEED_S_7A1',
                 'NOCURRENTBREASTFEED_S_8A1', 'NOCURRENTBREASTFEED_S_9A1', 'NOCURRENTBREASTFEED_S_10A1',
                 'NOCURRENTBREASTFEED_S_11A1', 'NOCURRENTBREASTFEED_S_12A1', 'NOCURRENTBREASTFEED_S_13A1',
                 'NOCURRENTBREASTFEED_S_14A1', 'NOCURRENTBREASTFEED_S_15A1', 'NOCURRENTBREASTFEED_S_16A1',
                 'NOCURRENTBREASTFEED_S_17A1', 'NOCURRENTBREASTFEED_S_18A1', 'NOCURRENTBREASTFEED_S_19A1',
                 'NOCURRENTBREASTFEED_S_20A1', 'NOCURRENTBREASTFEED_S_21A1', 'FORMULAMONTHS_S_1A1',
                 'FORMULAMONTHS_S_2A1', 'FORMULAMONTHS_S_3A1', 'FORMULAMONTHS_S_4A1', 'FORMULAMONTHS_S_5A1',
                 'FORMULAMONTHS_S_6A1', 'FORMULAMONTHS_S_7A1', 'FORMULAMONTHS_S_8A1', 'FORMULAMONTHS_S_9A1',
                 'FORMULAMONTHS_S_10A1', 'FORMULAMONTHS_S_11A1', 'FORMULAMONTHS_S_12A1', 'FORMULAMONTHS_S_13A1',
                 'FORMULAMONTHS_S_14A1', 'FORMULAMONTHS_S_15A1', 'FORMULAMONTHS_S_16A1', 'FORMULAMONTHS_S_17A1',
                 'FORMULAMONTHS_S_18A1', 'FORMULAMONTHS_S_19A1', 'FORMULAMONTHS_S_20A1', 'FORMULAMONTHS_S_21A1',
                 'CHILDCAREINTROA1', 'FAMILYDAYCAREMONTHS_S_1A1', 'FAMILYDAYCAREMONTHS_S_2A1',
                 'FAMILYDAYCAREMONTHS_S_3A1', 'FAMILYDAYCAREMONTHS_S_4A1', 'FAMILYDAYCAREMONTHS_S_5A1',
                 'FAMILYDAYCAREMONTHS_S_6A1', 'FAMILYDAYCAREMONTHS_S_7A1', 'FAMILYDAYCAREMONTHS_S_8A1',
                 'FAMILYDAYCAREMONTHS_S_9A1', 'FAMILYDAYCAREMONTHS_S_10A1', 'FAMILYDAYCAREMONTHS_S_11A1',
                 'FAMILYDAYCAREMONTHS_S_12A1', 'FAMILYDAYCAREMONTHS_S_13A1', 'FAMILYDAYCAREMONTHS_S_14A1',
                 'FAMILYDAYCAREMONTHS_S_15A1', 'FAMILYDAYCAREMONTHS_S_16A1', 'FAMILYDAYCAREMONTHS_S_17A1',
                 'FAMILYDAYCAREMONTHS_S_18A1', 'FAMILYDAYCAREMONTHS_S_19A1', 'FAMILYDAYCAREMONTHS_S_20A1',
                 'FAMILYDAYCAREMONTHS_S_21A1', 'DAYCAREMONTHS_S_1A1', 'DAYCAREMONTHS_S_2A1',
                 'DAYCAREMONTHS_S_3A1', 'DAYCAREMONTHS_S_4A1', 'DAYCAREMONTHS_S_5A1', 'DAYCAREMONTHS_S_6A1',
                 'DAYCAREMONTHS_S_7A1', 'DAYCAREMONTHS_S_8A1', 'DAYCAREMONTHS_S_9A1', 'DAYCAREMONTHS_S_10A1',
                 'DAYCAREMONTHS_S_11A1', 'DAYCAREMONTHS_S_12A1', 'DAYCAREMONTHS_S_13A1', 'DAYCAREMONTHS_S_14A1',
                 'DAYCAREMONTHS_S_15A1', 'DAYCAREMONTHS_S_16A1', 'DAYCAREMONTHS_S_17A1', 'DAYCAREMONTHS_S_18A1',
                 'DAYCAREMONTHS_S_19A1', 'DAYCAREMONTHS_S_20A1', 'DAYCAREMONTHS_S_21A1',
                 'OTHERCAREINTROA1', 'OCARE_S_1A1', 'OCARE_S_2A1', 'OCARE_S_3A1', 'OCARE_S_4A1', 'OCARE_S_5A1',
                 'OCARE_S_6A1', 'SCHEDMAINOA1', 'WORKISSUESA1', 'WORKISSUESOA1', 'MHEALTHINTRO1A1',
                 'HINTROA1', 'TOTALEARNEDVERA1', 'EARNED10KPLUSA1', 'EARNED15KPLUSA1', 'EARNED20KPLUSA1',
                 'EARNED25KPLUSA1', 'EARNED5KPLUSA1', 'SPOUSETOTALEARNEDVERA1', 'SPEARNED10KPLUSA1',
                 'SPEARNED15KPLUSA1', 'SPEARNED20KPLUSA1', 'SPEARNED25KPLUSA1', 'SPEARNED5KPLUSA1',
                 'OTHERSTOTALEARNEDVERA1', 'OEARNED10KPLUSA1', 'OEARNED15KPLUSA1', 'OEARNED20KPLUSA1',
                 'OEARNED25KPLUSA1', 'OEARNED5KPLUSA1', 'GOVTINCOMEVERA1', 'GOVTRCVD10KPLUSA1',
                 'GOVTRCVD15KPLUSA1', 'GOVTRCVD20KPLUSA1', 'GOVTRCVD25KPLUSA1', 'GOVTRCVD5KPLUSA1',
                 'ALLOTHERSINCOMEVERA1', 'ALLOTHER10KPLUSA1', 'ALLOTHER15KPLUSA1', 'ALLOTHER20KPLUSA1',
                 'ALLOTHER25KPLUSA1', 'ALLOTHER5KPLUSA1', 'PAINTROA1', 'SERVICESSPEC_ANSWERA1',
                 'EEYEARINTROA1', 'ITEMSPURCHASEDA1', 'EEP30DINTROA1', 'FINANCESECTIONA1',
                 'L19_20_TIMESTAMPA1', 'FOODSTAMPSA1', 'OFOODAMTA1', 'FOODSTRESSINTROA1',
                 'OTHERSUPPORTA1', 'OSUPPORTAMTA1', 'HHCOUNTA1', 'MHEALTHINTRO2A1', 'DONE_B_1A1',
                 'INTRO_B_4A1', 'CLANGINTRO_B_1A1', 'SECR_DONEA1', 'INTRO_B_5A1', 'DADNAMEFA1', 'DADNAMEFOA1',
                 'DADNAMEMA1', 'DADNAMELA1', 'DADFIRSTNAMEA1', 'MFINTROA1', 'MFMARRIEDA1', 'MFSEPARATEDA1',
                 'MFNMARRIEDA1', 'MFPLANSA1', 'MMARRIEDA1', 'MMARRYMONTHA1', 'MMARRYYEARA1', 'MRELATETYPE_SPECA1',
                 'CURRRELNAMEA1', 'CURRRELGENDERA1', 'DADEMPINTROA1', 'DADETHNIC_S_1A1', 'DADETHNIC_S_2A1',
                 'DADETHNIC_S_3A1', 'DADETHNIC_S_4A1', 'DADETHNIC_S_5A1', 'DADETHNICOA1', 'DADRACE_S_2A1',
                 'DADRACE_S_3A1', 'DADRACEOA1', 'DADINVOLVEINTROA1', 'DADOVERNIGHTA1', 'DADOVERTIMESA1',
                 'PARTNERINTROA1', 'PARTNERINTRO2A1', 'SPOUSECOUNTA1', 'PARTNERCOUNTA1', 'RESIDENTINTROA1',
                 'MOMHOUSINGA1', 'MOMOWNSPECA1', 'MOMCURRHOUSEA1', 'CHEALTHINTROA1', 'CONMEDSA1',
                 'CMEDICATEA1', 'MISSMEDCAREA1', 'WHYMISSMEDCARE_S_1A1', 'WHYMISSMEDCARE_S_3A1', 'WHYMISSMEDCARE_S_2A1',
                 'WHYMISSMEDCARE_S_4A1', 'CSOCINTROA1', 'CLANGINTRO_B_2A1', 'CPRIMLANGA1',
                 'MOSTCOMMONOTHLANGA1', 'COTHERLANGA1', 'COTHLANGSPEC_S_1A1', 'COTHLANGSPEC_S_2A1',
                 'COTHLANGSPEC_S_3A1', 'OTHERLANGUAGESA1', 'CPRIMLANGTA1', 'HHATMINTROA1', 'PARENTSTRESSA1',
                 'MSLEEPINTROA1', 'IWER_CKPT1_B_1A1', 'IWER_CKPT2_B_1A1', 'IWER_CKPT3_B_1A1',
                 'IWER_CKPT4_B_1A1', 'DONE_B_5A1', 'INTRO_B_6A1', 'PB7_HOLDA1', 'ACASI_INTROA1',
                 'ACASI_INTRO1A1', 'ACASI_INTRO2A1', 'ROMANCEINTROA1', 'BEHAVIORINTROA1', 'DISCINTROA1',
                 'MOMPREGA1', 'PLANNEDPREGA1', 'OTHERCONTRAA1', 'DONE_B_6A1', 'HOLD_B_7A1', 'INTRO_B_7A1',
                 'IWER_CKPT1_B_2A1', 'IWER_CKPT2_B_2A1', 'IWER_CKPT3_B_2A1', 'IWER_CKPT4_B_2A1', 'NOHAIR_B_2A1',
                 'CONFIRMHAIR_B_2A1', 'WHYNOHAIR_B_2A1', 'WEIRDHAIR_B_2A1', 'DONE_B_7A1', 'INTRO_B_8A1',
                 'OBSRLOCATIONOA1', 'OBSASSISTANTA1', 'OBSROTHERSA1', 'OBSROTHERSLISTA1', 'OBSRREVEALA1',
                 'DONE_B_8A1', 'FINALTASKRULESTATEA1', 'PHONEIWA1', 'ANYIWDONEA1', 'SITE_LAA1', 'SITE_MNA1',
                 'SITE_NEA1', 'SITE_NYA1', 'PUBLICSAMPLEID', 'PHONEIWV2A1', 'CFEMALEA1', 'MWHITEA1',
                 'MBLACKA1', 'MRACEMULTIPLEA1', 'MRACEOTHERA1', 'MHISPANICA1', 'MRACEA1', 'MWHITEHISPA1',
                 'MBLACKHISPA1', 'MRACEMULTIPLEHISPA1', 'MRACEOTHERHISPA1', 'MRACEUNKA1', 'MRACEUNKHISPA1',
                 'MRACEEXPA1', 'MMEXICANA1', 'MPUERTORICANA1', 'MDOMINICANA1', 'MCUBANA1', 'METHNICITYOTHERA1',
                 'METHNICITYMULTIPLEA1', 'METHNICITYA1', 'DUNKNOWNA0A1', 'DUNKNOWNA1A1', 'DWHITEA1',
                 'DBLACKA1', 'DRACEMULTIPLEA1', 'DRACEOTHERA1', 'DHISPANICA1', 'DRACEA1', 'DMEXICANA1',
                 'DPUERTORICANA1', 'DDOMINICANA1', 'DCUBANA1', 'DETHNICITYOTHERA1', 'DETHNICITYMULTIPLEA1',
                 'DETHNICITYA1', 'DEDUTRAINA1', 'DJOBTRAINA1', 'DWORKA1', 'DSELFEMPA1', 'DEMPLOYEDA1',
                 'DEDJOBTRAINA1', 'DJAILA1', 'DPAROLEA1', 'MPREGA1', 'MPLANPREGA1', 'MPLANCHILDA1',
                 'MTUBESTIEDA1', 'MSTERILIZATIONA1', 'MSHORTTERMCONTRAA1', 'MLONGTERMCONTRAA1',
                 'MSHORTHORMCONTRAA1', 'MCYCLETRACKA1', 'MMORNINGAFTERA1', 'MNOCONTRAA1', 'MRMOVEDA1',
                 'MHOUSEA1', 'HHHOMELESSORSHELTERA1', 'MMFORECLOSEA1']

df_bfy = df_bfy.drop(cols_to_remove, axis=1)
df_bfy.shape
# Out:
# (1000, 1332)
